# %%
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
from collections.abc import Callable
from typing import Literal
import torch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def fn_plot_torch_hist(hist_df):
    
    # instantiate figure
    fig, axes = plt.subplots(1,2 , figsize = (15,6))
    
    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='cyan', alpha=0.5)

    # columns
    x = hist_df.columns[0]
    y1 = hist_df.columns[1]
    y2 = hist_df.columns[2]
    y3 = hist_df.columns[3]
    y4 = hist_df.columns[4]
    
    # Where was min loss
    best = hist_df[hist_df[y2] == hist_df[y2].min()]
    best = best.drop_duplicates(subset=y2)
    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1, y2], ax = ax)

    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y2].min())
    y_max = max(hist_df[y1].max(), hist_df[y2].max())
    offset = (y_max-y_min)/10.0

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()+ offset, best[y2].to_numpy()[0]+offset), # location of text 
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow
    
    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(), color = 'green', linestyle='-.', lw = 3);
    
    ax.set_xlabel(x.title())
    ax.set_ylabel(y1.title())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracies
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot
        
    # calculate offset for arroe
    y_min = min(hist_df[y3].min(), hist_df[y4].min())
    y_max = max(hist_df[y3].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()- offset, best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow
    
    
    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(), 
               color = 'green', 
               linestyle='-.', lw = 3)
    
    # Labels
    ax.set_xlabel(x.title())
    ax.set_ylabel(y3.title())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()


def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
inpDir = 'D:\DNN\input' # location where input data is stored
outDir = '../output' # location to store outputs
subDir = 'D:\DNN\images' # location of the images
modelDir = '../models'
altName = '?????'

RANDOM_STATE = 24
torch.manual_seed(RANDOM_STATE) # Set Random Seed for reproducible  results
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed=RANDOM_STATE)
EPOCHS = 101 # number of epochs
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
BATCH_SIZE = 32
REG_LAMBDA = 0.001
# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'medium',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'fifa_2019.csv'))
data_df.shape
# Out:
# (18207, 89)

# %%
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
data_df = data_df[rel_cols]
data_df.head()
# Out:
#    Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0         3       95.0             70.0          90.0     86.0       97.0
# 1         3       94.0             89.0          81.0     87.0       88.0
# 2         3       87.0             62.0          84.0     84.0       96.0
# 3         0       13.0             21.0          50.0     13.0       18.0
# 4         2       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
class_labels = {0: 'GK', 1: 'Defender', 2: 'Mid Fielder', 3 : 'Forward'}

# %%
y = data_df["Position"].to_numpy()

X = data_df.drop("Position", axis = 1)

X.shape, y.shape
# Out:
# ((18147, 33), (18147,))

# %%
#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE, 
                                                    stratify=y, 
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (14517, 33) (14517,) (3630, 33) (3630,)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.16.1'

# %%
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)

k_reg = None
dor1 = 0.02
dor2 = 0.15
dor3 = 0.25
dor4 = 0.35
#k_reg = tf.keras.regularizers.L2(l2 = REG_LAMBDA)
model = tf.keras.Sequential([ 
    tf.keras.layers.InputLayer(shape = (33,)),

    tf.keras.layers.Dense(33,kernel_initializer = k_init , kernel_regularizer=k_reg),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dropout(dor1),

    tf.keras.layers.Dense(23,kernel_initializer = k_init , kernel_regularizer=k_reg),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dropout(dor2),

    tf.keras.layers.Dense(12, kernel_initializer = k_init , kernel_regularizer=k_reg),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dropout(dor3),

    tf.keras.layers.Dense(4, kernel_initializer = k_init , kernel_regularizer=k_reg),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dropout(dor4),

    tf.keras.layers.Dense(4)
    
])

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=array([[0.09438614, 0.11566927, 0.30572808, 0.16379595]], dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)

# %%
model.compile(optimizer=optimizer, loss = loss_fn , metrics=['accuracy'])

history = model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=BATCH_SIZE,epochs=EPOCHS,verbose=2)
# Out:
# Epoch 1/101
# 454/454 - 6s - 13ms/step - accuracy: 0.5177 - loss: 1.0848 - val_accuracy: 0.7369 - val_loss: 0.7070
# Epoch 2/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6255 - loss: 0.8388 - val_accuracy: 0.8399 - val_loss: 0.5531
# Epoch 3/101
# 454/454 - 3s - 6ms/step - accuracy: 0.6606 - loss: 0.7717 - val_accuracy: 0.8573 - val_loss: 0.5069
# Epoch 4/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6862 - loss: 0.7306 - val_accuracy: 0.8675 - val_loss: 0.4691
# Epoch 5/101
# 454/454 - 3s - 6ms/step - accuracy: 0.6906 - loss: 0.7160 - val_accuracy: 0.8708 - val_loss: 0.4601
# Epoch 6/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7078 - loss: 0.6926 - val_accuracy: 0.8727 - val_loss: 0.4315
# Epoch 7/101
# 454/454 - 3s - 6ms/step - accuracy: 0.6980 - loss: 0.6974 - val_accuracy: 0.8686 - val_loss: 0.4295
# Epoch 8/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6982 - loss: 0.6812 - val_accuracy: 0.8667 - val_loss: 0.4161
# Epoch 9/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7048 - loss: 0.6715 - val_accuracy: 0.8639 - val_loss: 0.4113
# Epoch 10/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7043 - loss: 0.6718 - val_accuracy: 0.8639 - val_loss: 0.4035
# Epoch 11/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7026 - loss: 0.6662 - val_accuracy: 0.8708 - val_loss: 0.4051
# Epoch 12/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7003 - loss: 0.6698 - val_accuracy: 0.8678 - val_loss: 0.3987
# Epoch 13/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6950 - loss: 0.6635 - val_accuracy: 0.8669 - val_loss: 0.4005
# Epoch 14/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7043 - loss: 0.6456 - val_accuracy: 0.8658 - val_loss: 0.3921
# Epoch 15/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6990 - loss: 0.6464 - val_accuracy: 0.8730 - val_loss: 0.3897
# Epoch 16/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6913 - loss: 0.6468 - val_accuracy: 0.8639 - val_loss: 0.3886
# Epoch 17/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6898 - loss: 0.6487 - val_accuracy: 0.8730 - val_loss: 0.3879
# Epoch 18/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6884 - loss: 0.6555 - val_accuracy: 0.8650 - val_loss: 0.3860
# Epoch 19/101
# 454/454 - 3s - 6ms/step - accuracy: 0.6926 - loss: 0.6344 - val_accuracy: 0.8694 - val_loss: 0.3824
# Epoch 20/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6813 - loss: 0.6508 - val_accuracy: 0.8736 - val_loss: 0.3817
# Epoch 21/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6881 - loss: 0.6387 - val_accuracy: 0.8716 - val_loss: 0.3862
# Epoch 22/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6855 - loss: 0.6406 - val_accuracy: 0.8680 - val_loss: 0.3810
# Epoch 23/101
# 454/454 - 3s - 6ms/step - accuracy: 0.6786 - loss: 0.6439 - val_accuracy: 0.8711 - val_loss: 0.3866
# Epoch 24/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6833 - loss: 0.6289 - val_accuracy: 0.8716 - val_loss: 0.3713
# Epoch 25/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6818 - loss: 0.6324 - val_accuracy: 0.8716 - val_loss: 0.3717
# Epoch 26/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6835 - loss: 0.6336 - val_accuracy: 0.8719 - val_loss: 0.3714
# Epoch 27/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6961 - loss: 0.6233 - val_accuracy: 0.8749 - val_loss: 0.3707
# Epoch 28/101
# 454/454 - 2s - 4ms/step - accuracy: 0.6956 - loss: 0.6283 - val_accuracy: 0.8733 - val_loss: 0.3695
# Epoch 29/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6975 - loss: 0.6194 - val_accuracy: 0.8680 - val_loss: 0.3719
# Epoch 30/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6986 - loss: 0.6258 - val_accuracy: 0.8675 - val_loss: 0.3732
# Epoch 31/101
# 454/454 - 2s - 5ms/step - accuracy: 0.6987 - loss: 0.6240 - val_accuracy: 0.8702 - val_loss: 0.3644
# Epoch 32/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7057 - loss: 0.6176 - val_accuracy: 0.8683 - val_loss: 0.3653
# Epoch 33/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7088 - loss: 0.6150 - val_accuracy: 0.8716 - val_loss: 0.3615
# Epoch 34/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7079 - loss: 0.6168 - val_accuracy: 0.8675 - val_loss: 0.3680
# Epoch 35/101
# 454/454 - 1s - 3ms/step - accuracy: 0.7094 - loss: 0.6115 - val_accuracy: 0.8661 - val_loss: 0.3590
# Epoch 36/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7067 - loss: 0.6178 - val_accuracy: 0.8702 - val_loss: 0.3597
# Epoch 37/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7089 - loss: 0.6177 - val_accuracy: 0.8727 - val_loss: 0.3610
# Epoch 38/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7177 - loss: 0.6079 - val_accuracy: 0.8697 - val_loss: 0.3540
# Epoch 39/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7112 - loss: 0.6068 - val_accuracy: 0.8694 - val_loss: 0.3585
# Epoch 40/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7181 - loss: 0.6076 - val_accuracy: 0.8625 - val_loss: 0.3568
# Epoch 41/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7137 - loss: 0.6162 - val_accuracy: 0.8752 - val_loss: 0.3552
# Epoch 42/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7151 - loss: 0.6136 - val_accuracy: 0.8755 - val_loss: 0.3511
# Epoch 43/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7149 - loss: 0.6067 - val_accuracy: 0.8702 - val_loss: 0.3589
# Epoch 44/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7201 - loss: 0.6000 - val_accuracy: 0.8711 - val_loss: 0.3523
# Epoch 45/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7196 - loss: 0.6040 - val_accuracy: 0.8680 - val_loss: 0.3566
# Epoch 46/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7246 - loss: 0.5959 - val_accuracy: 0.8672 - val_loss: 0.3571
# Epoch 47/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7223 - loss: 0.5999 - val_accuracy: 0.8612 - val_loss: 0.3554
# Epoch 48/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7170 - loss: 0.6118 - val_accuracy: 0.8603 - val_loss: 0.3561
# Epoch 49/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7172 - loss: 0.6019 - val_accuracy: 0.8689 - val_loss: 0.3529
# Epoch 50/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7176 - loss: 0.5989 - val_accuracy: 0.8702 - val_loss: 0.3547
# Epoch 51/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7165 - loss: 0.6031 - val_accuracy: 0.8793 - val_loss: 0.3507
# Epoch 52/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7174 - loss: 0.5995 - val_accuracy: 0.8700 - val_loss: 0.3488
# Epoch 53/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7181 - loss: 0.6021 - val_accuracy: 0.8711 - val_loss: 0.3500
# Epoch 54/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7135 - loss: 0.6112 - val_accuracy: 0.8738 - val_loss: 0.3510
# Epoch 55/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7162 - loss: 0.6013 - val_accuracy: 0.8664 - val_loss: 0.3524
# Epoch 56/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7120 - loss: 0.6011 - val_accuracy: 0.8755 - val_loss: 0.3568
# Epoch 57/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7172 - loss: 0.5954 - val_accuracy: 0.8752 - val_loss: 0.3493
# Epoch 58/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7164 - loss: 0.6022 - val_accuracy: 0.8661 - val_loss: 0.3510
# Epoch 59/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7169 - loss: 0.5921 - val_accuracy: 0.8702 - val_loss: 0.3503
# Epoch 60/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7198 - loss: 0.6005 - val_accuracy: 0.8766 - val_loss: 0.3534
# Epoch 61/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7211 - loss: 0.5951 - val_accuracy: 0.8780 - val_loss: 0.3531
# Epoch 62/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7184 - loss: 0.6099 - val_accuracy: 0.8705 - val_loss: 0.3552
# Epoch 63/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7254 - loss: 0.6007 - val_accuracy: 0.8747 - val_loss: 0.3446
# Epoch 64/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7200 - loss: 0.5904 - val_accuracy: 0.8736 - val_loss: 0.3431
# Epoch 65/101
# 454/454 - 2s - 6ms/step - accuracy: 0.7173 - loss: 0.5995 - val_accuracy: 0.8738 - val_loss: 0.3481
# Epoch 66/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7185 - loss: 0.5964 - val_accuracy: 0.8744 - val_loss: 0.3563
# Epoch 67/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7139 - loss: 0.6133 - val_accuracy: 0.8733 - val_loss: 0.3453
# Epoch 68/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7181 - loss: 0.5963 - val_accuracy: 0.8725 - val_loss: 0.3472
# Epoch 69/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7156 - loss: 0.6066 - val_accuracy: 0.8727 - val_loss: 0.3552
# Epoch 70/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7246 - loss: 0.5891 - val_accuracy: 0.8738 - val_loss: 0.3504
# Epoch 71/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7186 - loss: 0.6082 - val_accuracy: 0.8755 - val_loss: 0.3506
# Epoch 72/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7254 - loss: 0.5940 - val_accuracy: 0.8747 - val_loss: 0.3516
# Epoch 73/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7218 - loss: 0.5962 - val_accuracy: 0.8727 - val_loss: 0.3529
# Epoch 74/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7208 - loss: 0.5949 - val_accuracy: 0.8736 - val_loss: 0.3499
# Epoch 75/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7226 - loss: 0.5941 - val_accuracy: 0.8749 - val_loss: 0.3538
# Epoch 76/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7183 - loss: 0.6049 - val_accuracy: 0.8738 - val_loss: 0.3508
# Epoch 77/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7257 - loss: 0.5827 - val_accuracy: 0.8747 - val_loss: 0.3460
# Epoch 78/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7192 - loss: 0.5940 - val_accuracy: 0.8747 - val_loss: 0.3502
# Epoch 79/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7183 - loss: 0.5967 - val_accuracy: 0.8694 - val_loss: 0.3487
# Epoch 80/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7210 - loss: 0.5949 - val_accuracy: 0.8711 - val_loss: 0.3505
# Epoch 81/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7235 - loss: 0.5960 - val_accuracy: 0.8769 - val_loss: 0.3559
# Epoch 82/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7187 - loss: 0.5926 - val_accuracy: 0.8672 - val_loss: 0.3556
# Epoch 83/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7187 - loss: 0.5925 - val_accuracy: 0.8689 - val_loss: 0.3543
# Epoch 84/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7216 - loss: 0.5959 - val_accuracy: 0.8702 - val_loss: 0.3573
# Epoch 85/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7128 - loss: 0.6053 - val_accuracy: 0.8614 - val_loss: 0.3583
# Epoch 86/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7192 - loss: 0.6053 - val_accuracy: 0.8722 - val_loss: 0.3548
# Epoch 87/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7193 - loss: 0.5903 - val_accuracy: 0.8782 - val_loss: 0.3506
# Epoch 88/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7147 - loss: 0.5973 - val_accuracy: 0.8760 - val_loss: 0.3525
# Epoch 89/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7240 - loss: 0.5774 - val_accuracy: 0.8727 - val_loss: 0.3526
# Epoch 90/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7156 - loss: 0.5924 - val_accuracy: 0.8719 - val_loss: 0.3503
# Epoch 91/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7178 - loss: 0.5892 - val_accuracy: 0.8680 - val_loss: 0.3558
# Epoch 92/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7194 - loss: 0.5923 - val_accuracy: 0.8733 - val_loss: 0.3558
# Epoch 93/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7234 - loss: 0.5968 - val_accuracy: 0.8769 - val_loss: 0.3474
# Epoch 94/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7145 - loss: 0.5946 - val_accuracy: 0.8686 - val_loss: 0.3482
# Epoch 95/101
# 454/454 - 3s - 6ms/step - accuracy: 0.7192 - loss: 0.6012 - val_accuracy: 0.8719 - val_loss: 0.3531
# Epoch 96/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7250 - loss: 0.5970 - val_accuracy: 0.8727 - val_loss: 0.3554
# Epoch 97/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7166 - loss: 0.6026 - val_accuracy: 0.8716 - val_loss: 0.3486
# Epoch 98/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7145 - loss: 0.5933 - val_accuracy: 0.8716 - val_loss: 0.3528
# Epoch 99/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7207 - loss: 0.5948 - val_accuracy: 0.8760 - val_loss: 0.3479
# Epoch 100/101
# 454/454 - 2s - 4ms/step - accuracy: 0.7180 - loss: 0.5909 - val_accuracy: 0.8683 - val_loss: 0.3531
# Epoch 101/101
# 454/454 - 2s - 5ms/step - accuracy: 0.7158 - loss: 0.5937 - val_accuracy: 0.8752 - val_loss: 0.3530

# %%
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss 
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y2 = hist_df.columns[0] 
    y1 = hist_df.columns[1] 
    y4 = hist_df.columns[2]
    y3 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.517669  1.084781      0.736915  0.707040
# 1  0.625542  0.838773      0.839945  0.553121
# 2  0.660605  0.771728      0.857300  0.506886
# 3  0.686161  0.730640      0.867493  0.469113
# 4  0.690639  0.716020      0.870799  0.460050

# %%
fig, axes = plt.subplots(1,2 , figsize = (15,6),)

l_range = 10 # ignoring first few records
y1_var = 'loss'
y2_var = 'val_loss'

ax = axes[0]

loss_df[[y1_var, y2_var]].plot( ax = ax)

# get values for plotting
st_loss = loss_df[y1_var].iloc[0]
end_loss = loss_df[y1_var].iloc[-1]
t_st_loss = loss_df[y2_var].iloc[0]
t_end_loss = loss_df[y2_var].iloc[-1]

# little beautification
train_txtstr = "Train Loss: \n  Start : {:7.4f}\n    End : {:7.4f}".format( st_loss, end_loss )    # Train text to plot

test_txtstr = "Test Loss: \n  Start : {:7.4f}\n    End : {:7.4f}".format( t_st_loss, t_end_loss ) # Test text to plot
txtstr = ' {} \n{}'.format(train_txtstr, test_txtstr)
# properties  matplotlib.patch.Patch 
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords

ax.text(0.4, 0.95, txtstr, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_xlabel('epoch')
ax.set_ylabel(y1_var)
ax.set_title('Overall')
ax.grid();

ax = axes[1]

y1_var = 'accuracy'
y2_var = 'val_accuracy'

loss_df[[y1_var, y2_var]].plot( ax = ax)

# get values for plotting
st_loss = loss_df[y1_var].iloc[0]
end_loss = loss_df[y1_var].iloc[-1]
t_st_loss = loss_df[y2_var].iloc[0]
t_end_loss = loss_df[y2_var].iloc[-1]

# little beautification
train_txtstr = "Train Accuracy: \n  Start : {:7.4f}\n    End : {:7.4f}".format( st_loss, end_loss )    # Train text to plot

test_txtstr = "Test Accuracy: \n  Start : {:7.4f}\n    End : {:7.4f}".format( t_st_loss, t_end_loss ) # Test text to plot# properties  matplotlib.patch.Patch 
txtstr = ' {} \n{}'.format(train_txtstr, test_txtstr)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords

ax.text(0.4, 0.95, txtstr, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_xlabel('epoch')
ax.set_ylabel(y1_var)
ax.set_title('Accuracies'.format(l_range))
ax.grid();
plt.tight_layout()

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

from collections.abc import Callable
from typing import Literal

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

#from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###----------------------
### Some basic parameters
###----------------------
inpDir = "D:\DNN\input" # location where input data is stored
outDir = '../output' # location to store outputs
modelDir = os.path.join('..','..','models')
subDir = 'fifa_2019' # location of the images
logDir = '../logs'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 1000 # number of epochs
BATCH_SIZE = 32
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
REG_LAMBDA = 0.001


PATIENCE =20
LR_PATIENCE = 10
LR_FACTOR=0.1


# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'medium',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'fifa_2019.csv'))
data_df.shape
# Out:
# (18207, 89)

# %%
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS', 'LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
data_df = data_df[rel_cols]
data_df.head()
# Out:
#    Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0         3       95.0             70.0          90.0     86.0       97.0
# 1         3       94.0             89.0          81.0     87.0       88.0
# 2         3       87.0             62.0          84.0     84.0       96.0
# 3         0       13.0             21.0          50.0     13.0       18.0
# 4         2       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
features_df =  data_df.drop('Position', axis=1)
labels = data_df['Position']

# %%
# splitting in train ans test datasets
X_train, X_test, y_train, y_test = train_test_split(features_df, labels,
                                     stratify=labels,
                                     test_size=TEST_SIZE, 
                                     random_state=RANDOM_STATE )
X_train.shape
# Out:
# (14517, 33)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#X_train = X_train.to_numpy()
#y_test = y_test.to_numpy()

# %%
import tensorflow as tf

from tensorflow import keras
tf.__version__
# Out:
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# '2.15.1'

# %%
#pip uninstall tf

# %%
#pip install tensorflow==2.15.1

# %%
import tensorflow as tf

from tensorflow import keras
tf.__version__
# Out:
# '2.15.1'

# %%
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)
#k_reg = tf.keras.regularizers.L2(l2=REG_LAMBDA)
k_reg =None

###Dropout Rates
dor1 = 0.10
dor2 = 0.075
dor3 = 0.050
dor4 = 0.050


model = tf.keras.Sequential([
    
    #Input Layer
    tf.keras.layers.InputLayer(input_shape=(33, )),
    
    ###Set1
    tf.keras.layers.Dense(33, #activation = 'relu', 
                          kernel_initializer=k_init,
                          kernel_regularizer=k_reg),
    ###BNlayer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    
    #DO layer
    #tf.keras.layers.Dropout(dor1),
    
    ###Set2
    tf.keras.layers.Dense(23,# activation = 'relu', 
                          kernel_initializer=k_init, 
                          kernel_regularizer=k_reg),
    ###BNlayer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    
    #DO layer
   # tf.keras.layers.Dropout(dor2),
    
    ###Set3
    tf.keras.layers.Dense(12, #activation = 'relu',
                          kernel_initializer=k_init, 
                          kernel_regularizer=k_reg),
    ###BNlayer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    
    #DO layer
    #tf.keras.layers.Dropout(dor3),
    
    ###Set4
    tf.keras.layers.Dense(4, #activation = 'relu', 
                          kernel_initializer=k_init, 
                          kernel_regularizer=k_reg),
    ###BNlayer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    
    #DO layer
    #tf.keras.layers.Dropout(dor4),
    
    #Output layer
    tf.keras.layers.Dense(4)
])
# Out:
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %% [markdown]
# ### Call backs

# %%
checkpoint_path = os.path.join('..','..','models', subDir)
checkpoint_path
# Out:
# '..\\..\\models\\fifa_2019'

# %%
isExist = os.path.exists(checkpoint_path)
isExist
# Out:
# True

# %%
checkpoint_path = os.path.join(modelDir, subDir ,'fifa.weights.h5')

model_ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    verbose=2,
    save_best_only=True,
    save_weights_only=True,
    mode='auto')

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    verbose=2,
    mode='auto',
    restore_best_weights=True
)


lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=2,
    mode='auto',
    min_lr=0.00001
)

log_dir = os.path.join(logDir,'fit')
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.08476119, -0.17110597, -0.12039672,  0.12114552]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)


optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    callbacks = [model_ckpt_callback,
                                 es_callback,
                                 lr_callback,
                                 tb_callback],
                    verbose=2)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
# Epoch 1: val_loss improved from inf to 0.59160, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 8s - loss: 0.8426 - accuracy: 0.7403 - val_loss: 0.5916 - val_accuracy: 0.8083 - lr: 0.0010 - 8s/epoch - 17ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.59160 to 0.44349, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 2s - loss: 0.5448 - accuracy: 0.8299 - val_loss: 0.4435 - val_accuracy: 0.8587 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.44349 to 0.37925, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.4428 - accuracy: 0.8550 - val_loss: 0.3793 - val_accuracy: 0.8680 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.37925 to 0.33209, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.3772 - accuracy: 0.8598 - val_loss: 0.3321 - val_accuracy: 0.8664 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.33209 to 0.31469, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 2s - loss: 0.3444 - accuracy: 0.8633 - val_loss: 0.3147 - val_accuracy: 0.8705 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.31469 to 0.30890, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.3326 - accuracy: 0.8635 - val_loss: 0.3089 - val_accuracy: 0.8719 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.30890 to 0.30729, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.3312 - accuracy: 0.8659 - val_loss: 0.3073 - val_accuracy: 0.8730 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 0.30729 to 0.29981, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.3169 - accuracy: 0.8696 - val_loss: 0.2998 - val_accuracy: 0.8769 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.29981
# 454/454 - 2s - loss: 0.3145 - accuracy: 0.8731 - val_loss: 0.3005 - val_accuracy: 0.8774 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 0.29981 to 0.29540, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.3104 - accuracy: 0.8717 - val_loss: 0.2954 - val_accuracy: 0.8802 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.29540
# 454/454 - 2s - loss: 0.3113 - accuracy: 0.8726 - val_loss: 0.2962 - val_accuracy: 0.8793 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.29540
# 454/454 - 3s - loss: 0.3045 - accuracy: 0.8744 - val_loss: 0.2978 - val_accuracy: 0.8785 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.29540
# 454/454 - 2s - loss: 0.3050 - accuracy: 0.8719 - val_loss: 0.2970 - val_accuracy: 0.8782 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.29540
# 454/454 - 2s - loss: 0.3052 - accuracy: 0.8750 - val_loss: 0.2957 - val_accuracy: 0.8777 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.29540
# 454/454 - 3s - loss: 0.3035 - accuracy: 0.8736 - val_loss: 0.2971 - val_accuracy: 0.8763 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.29540
# 454/454 - 2s - loss: 0.3054 - accuracy: 0.8734 - val_loss: 0.2959 - val_accuracy: 0.8771 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.29540
# 454/454 - 2s - loss: 0.2971 - accuracy: 0.8774 - val_loss: 0.2967 - val_accuracy: 0.8760 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.29540
# 454/454 - 3s - loss: 0.2965 - accuracy: 0.8776 - val_loss: 0.2963 - val_accuracy: 0.8782 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.29540
# 454/454 - 2s - loss: 0.2955 - accuracy: 0.8775 - val_loss: 0.3014 - val_accuracy: 0.8730 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.29540
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 454/454 - 2s - loss: 0.2956 - accuracy: 0.8783 - val_loss: 0.3004 - val_accuracy: 0.8733 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss improved from 0.29540 to 0.29481, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.2864 - accuracy: 0.8800 - val_loss: 0.2948 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss improved from 0.29481 to 0.29476, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 2s - loss: 0.2847 - accuracy: 0.8821 - val_loss: 0.2948 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 0.29476 to 0.29445, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 2s - loss: 0.2887 - accuracy: 0.8806 - val_loss: 0.2944 - val_accuracy: 0.8758 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss improved from 0.29445 to 0.29369, saving model to ..\..\models\fifa_2019\fifa.weights.h5
# 454/454 - 3s - loss: 0.2822 - accuracy: 0.8825 - val_loss: 0.2937 - val_accuracy: 0.8769 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2847 - accuracy: 0.8822 - val_loss: 0.2943 - val_accuracy: 0.8774 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2827 - accuracy: 0.8813 - val_loss: 0.2949 - val_accuracy: 0.8763 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.29369
# 454/454 - 3s - loss: 0.2818 - accuracy: 0.8814 - val_loss: 0.2942 - val_accuracy: 0.8760 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2842 - accuracy: 0.8848 - val_loss: 0.2942 - val_accuracy: 0.8755 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2841 - accuracy: 0.8814 - val_loss: 0.2950 - val_accuracy: 0.8769 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2865 - accuracy: 0.8799 - val_loss: 0.2948 - val_accuracy: 0.8774 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2832 - accuracy: 0.8826 - val_loss: 0.2949 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2828 - accuracy: 0.8828 - val_loss: 0.2945 - val_accuracy: 0.8758 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2832 - accuracy: 0.8820 - val_loss: 0.2945 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 0.29369
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 454/454 - 2s - loss: 0.2880 - accuracy: 0.8807 - val_loss: 0.2945 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2848 - accuracy: 0.8797 - val_loss: 0.2946 - val_accuracy: 0.8760 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2775 - accuracy: 0.8855 - val_loss: 0.2941 - val_accuracy: 0.8760 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2824 - accuracy: 0.8845 - val_loss: 0.2944 - val_accuracy: 0.8769 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2811 - accuracy: 0.8836 - val_loss: 0.2942 - val_accuracy: 0.8766 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2818 - accuracy: 0.8810 - val_loss: 0.2950 - val_accuracy: 0.8760 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.29369
# 454/454 - 3s - loss: 0.2812 - accuracy: 0.8814 - val_loss: 0.2941 - val_accuracy: 0.8760 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2811 - accuracy: 0.8848 - val_loss: 0.2946 - val_accuracy: 0.8763 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 0.29369
# 454/454 - 2s - loss: 0.2801 - accuracy: 0.8847 - val_loss: 0.2944 - val_accuracy: 0.8760 - lr: 1.0000e-05 - 2s/epoch - 5ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 0.29369
# 454/454 - 3s - loss: 0.2815 - accuracy: 0.8840 - val_loss: 0.2946 - val_accuracy: 0.8769 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 0.29369
# Restoring model weights from the end of the best epoch: 24.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-05.
# 454/454 - 3s - loss: 0.2811 - accuracy: 0.8836 - val_loss: 0.2943 - val_accuracy: 0.8755 - lr: 1.0000e-05 - 3s/epoch - 7ms/step
# Epoch 44: early stopping

# %%
def fn_plot_torch_hist(hist_df):
    
    # instantiate figure
    fig, axes = plt.subplots(1,2 , figsize = (15,6))
    
    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='cyan', alpha=0.5)

    # columns
    x = hist_df.columns[0]
    y1 = hist_df.columns[1]
    y2 = hist_df.columns[2]
    y3 = hist_df.columns[3]
    y4 = hist_df.columns[4]
    
    # Where was min loss
    best = hist_df[hist_df[y2] == hist_df[y2].min()]
    best = best.drop_duplicates(subset=y2)
    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1, y2], ax = ax)

    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y2].min())
    y_max = max(hist_df[y1].max(), hist_df[y2].max())
    offset = (y_max-y_min)/10.0

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()+ offset, best[y2].to_numpy()[0]+offset), # location of text 
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow
    
    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(), color = 'green', linestyle='-.', lw = 3);
    
    ax.set_xlabel(x.title())
    ax.set_ylabel(y1.title())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracies
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot
        
    # calculate offset for arroe
    y_min = min(hist_df[y3].min(), hist_df[y4].min())
    y_max = max(hist_df[y3].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()- offset, best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow
    
    
    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(), 
               color = 'green', 
               linestyle='-.', lw = 3)
    
    # Labels
    ax.set_xlabel(x.title())
    ax.set_ylabel(y3.title())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()


def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))

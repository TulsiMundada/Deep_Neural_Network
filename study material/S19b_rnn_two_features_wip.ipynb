# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 19b
#
# ## Simple RNN - Two Features
# Weather Data
# - Two features
#
# <img src='../../prasami_images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from datetime import datetime, timedelta

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

from utils.helper import fn_plot_tf_hist
# Out:
# 2024-05-12 18:58:39.900039: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-12 18:58:39.900081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-12 18:58:39.901048: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-12 18:58:39.906390: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-12 18:58:40.664739: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

EPOCHS = 20  # number of cycles to run
ALPHA = 0.001  # learning rate
TEST_SIZE = 0.2 # What fraction we want to keep for testing
BATCH_SIZE = 32

# Set parameters for decoration of plots
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }
CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Helper Function

# %%
### Settings so that Tensorflow can not Hog all the GPU memory
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2024-05-12 18:58:41.394105: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:41.430483: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:41.430774: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Load Weather Data
# Source: [Kaggle](https://www.kaggle.com/muthuj7/weather-dataset)

# %%
dataFilename = 'weatherHistory.csv'
data_df = pd.read_csv(os.path.join(inpDir, dataFilename))
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
data_df.shape
# Out:
# (96453, 12)

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'], 
                                     utc=True)

# %%
tmp_df = data_df[['datetime', 'Temperature (C)', 'Humidity', 'Wind Speed (km/h)']]
tmp_df = tmp_df.sort_values('datetime', axis=0, ascending=True)
tmp_df = tmp_df.reset_index(drop=True)
tmp_df.head()
# Out:
#                    datetime  Temperature (C)  Humidity  Wind Speed (km/h)
# 0 2005-12-31 23:00:00+00:00         0.577778      0.89            17.1143
# 1 2006-01-01 00:00:00+00:00         1.161111      0.85            16.6152
# 2 2006-01-01 01:00:00+00:00         1.666667      0.82            20.2538
# 3 2006-01-01 02:00:00+00:00         1.711111      0.82            14.4900
# 4 2006-01-01 03:00:00+00:00         1.183333      0.86            13.9426

# %%
tmp_df = tmp_df.rename({'Temperature (C)': 'temp',
                        'Humidity': 'hum',
                        'Wind Speed (km/h)': 'wind'}, axis=1)
tmp_df.head()
# Out:
#                    datetime      temp   hum     wind
# 0 2005-12-31 23:00:00+00:00  0.577778  0.89  17.1143
# 1 2006-01-01 00:00:00+00:00  1.161111  0.85  16.6152
# 2 2006-01-01 01:00:00+00:00  1.666667  0.82  20.2538
# 3 2006-01-01 02:00:00+00:00  1.711111  0.82  14.4900
# 4 2006-01-01 03:00:00+00:00  1.183333  0.86  13.9426

# %%
# comment uncomment following lines if you want part or full dataset

#startDate = pd.to_datetime('2007-1-1', utc=True)
#endDate = pd.to_datetime('2008-1-1', utc=True)
#temp_df = temp_df[(temp_df['datetime']  >= startDate) & (temp_df['datetime']  < endDate)]

# %% [markdown]
# ## Plotting samples

# %%
fig = plt.figure(figsize = (15,5))

ax = fig.add_subplot(1, 3, 1)
tmp_df.plot(x='datetime', y='temp', style=".", ax = ax);
ax.grid()
ax = fig.add_subplot(1, 3, 2)
tmp_df.plot(x='datetime', y='hum', style=".", ax = ax);
ax.grid()
ax = fig.add_subplot(1, 3, 3)
tmp_df.plot(x='datetime', y='wind', style=".", ax = ax);
ax.grid()

plt.tight_layout()

# %%
time_step = 24

# %%
y_idx = np.arange(time_step, tmp_df.shape[0], time_step)
y_df = tmp_df.iloc[y_idx][['datetime','temp']]
y_df.head()
# Out:
#                      datetime      temp
# 24  2006-01-01 23:00:00+00:00  5.422222
# 48  2006-01-02 23:00:00+00:00  1.694444
# 72  2006-01-03 23:00:00+00:00  2.200000
# 96  2006-01-04 23:00:00+00:00  1.666667
# 120 2006-01-05 23:00:00+00:00  1.805556

# %%
tmp_df = tmp_df.iloc[range(len(y_df) * time_step)]
tmp_df
# Out:
#                        datetime      temp   hum     wind
# 0     2005-12-31 23:00:00+00:00  0.577778  0.89  17.1143
# 1     2006-01-01 00:00:00+00:00  1.161111  0.85  16.6152
# 2     2006-01-01 01:00:00+00:00  1.666667  0.82  20.2538
# 3     2006-01-01 02:00:00+00:00  1.711111  0.82  14.4900
# 4     2006-01-01 03:00:00+00:00  1.183333  0.86  13.9426
# ...                         ...       ...   ...      ...
# 96427 2016-12-30 21:00:00+00:00 -0.427778  0.91   9.1931
# 96428 2016-12-30 22:00:00+00:00 -0.638889  0.92   9.1609
# 96429 2016-12-30 23:00:00+00:00 -0.872222  0.94   9.1126
# 96430 2016-12-31 00:00:00+00:00 -1.161111  0.95   8.9999
# 96431 2016-12-31 01:00:00+00:00 -1.488889  0.95   8.8711
#
# [96432 rows x 4 columns]

# %%
tmp_df['temp'].shape, tmp_df.shape
# Out:
# ((96432,), (96432, 4))

# %%
y_df.shape
# Out:
# (4018, 2)

# %%
X = tmp_df.to_numpy()

# %%
X[:, 1]
# Out:
# array([0.5777777777777773, 1.161111111111113, 1.6666666666666667, ...,
#        -0.8722222222222223, -1.161111111111111, -1.4888888888888887],
#       dtype=object)

# %%
X_temp = np.reshape(tmp_df['temp'].values, (y_df.shape[0], time_step))
X_hum = np.reshape(tmp_df['hum'].values, (y_df.shape[0], time_step))
X_wind = np.reshape(tmp_df['wind'].values, (y_df.shape[0], time_step))
X_temp.shape
# Out:
# (4018, 24)

# %%
X_temp = X_temp[:, :23]
X_hum = X_hum[:, :23]
X_wind = X_wind[:, :23]
X_wind.shape
# Out:
# (4018, 23)

# %% [markdown]
# ## Note
#
# Need to reshape the inputs into the 3D format as expected by the SimpleRNNs, namely [samples, timesteps, features].

# %%
X_data = np.stack((X_temp, X_hum), axis = 2)
X_data = np.reshape(X_data, (X_temp.shape[0], X_temp.shape[1], 2)) # Samples, timesteps, features
X_data.shape
# Out:
# (4018, 23, 2)

# %%
split = int(y_df.shape[0] * (1-TEST_SIZE))
X_train = X_data[:split]
X_test = X_data[split:]
y_train = y_df['temp'].values[:split]
y_test = y_df['temp'].values[split:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3214, 23, 2), (804, 23, 2), (3214,), (804,))

# %%
h_units = 256 # number of units in the RNN

input_shape=(time_step-1, X_train.shape[2] ) # we are using two features

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.SimpleRNN(units = h_units, 
                                    input_shape = input_shape, 
                                    activation = 'tanh'))

model.add(tf.keras.layers.Dense(1, activation = 'linear'))

model.compile(loss='mean_squared_error', optimizer='adam', 
              metrics=[tf.keras.metrics.RootMeanSquaredError()])
# Out:
# 2024-05-12 18:58:46.351671: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:46.352051: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:46.352342: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:46.431303: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:46.431652: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:46.431919: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-12 18:58:46.432073: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1177 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 256)               66304
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 66561 (260.00 KB)
# Trainable params: 66561 (260.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,
                    epochs=EPOCHS, 
                    validation_data=(X_test, y_test),
                    batch_size= BATCH_SIZE, 
                    verbose=1)
# Out:
# Epoch 1/20
# 2024-05-12 18:58:47.700237: I external/local_xla/xla/service/service.cc:168] XLA service 0x74a829a4f6c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-12 18:58:47.700264: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-05-12 18:58:47.705196: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-12 18:58:47.718661: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715520527.786761   34396 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 101/101 [==============================] - 2s 9ms/step - loss: 10.6737 - root_mean_squared_error: 3.2671 - val_loss: 0.9814 - val_root_mean_squared_error: 0.9906
# Epoch 2/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.5566 - root_mean_squared_error: 1.2476 - val_loss: 0.9016 - val_root_mean_squared_error: 0.9495
# Epoch 3/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.3272 - root_mean_squared_error: 1.1520 - val_loss: 0.7530 - val_root_mean_squared_error: 0.8678
# Epoch 4/20
# 101/101 [==============================] - 1s 6ms/step - loss: 1.2218 - root_mean_squared_error: 1.1053 - val_loss: 0.8139 - val_root_mean_squared_error: 0.9022
# Epoch 5/20
# 101/101 [==============================] - 1s 6ms/step - loss: 1.1208 - root_mean_squared_error: 1.0587 - val_loss: 0.8394 - val_root_mean_squared_error: 0.9162
# Epoch 6/20
# 101/101 [==============================] - 1s 6ms/step - loss: 1.1429 - root_mean_squared_error: 1.0691 - val_loss: 0.8686 - val_root_mean_squared_error: 0.9320
# Epoch 7/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.0658 - root_mean_squared_error: 1.0324 - val_loss: 0.6550 - val_root_mean_squared_error: 0.8093
# Epoch 8/20
# 101/101 [==============================] - 1s 6ms/step - loss: 1.0378 - root_mean_squared_error: 1.0187 - val_loss: 0.7735 - val_root_mean_squared_error: 0.8795
# Epoch 9/20
# 101/101 [==============================] - 1s 8ms/step - loss: 1.0501 - root_mean_squared_error: 1.0247 - val_loss: 0.8521 - val_root_mean_squared_error: 0.9231
# Epoch 10/20
# 101/101 [==============================] - 1s 9ms/step - loss: 4.8589 - root_mean_squared_error: 2.2043 - val_loss: 2.9031 - val_root_mean_squared_error: 1.7038
# Epoch 11/20
# 101/101 [==============================] - 1s 9ms/step - loss: 1.9979 - root_mean_squared_error: 1.4135 - val_loss: 1.3134 - val_root_mean_squared_error: 1.1460
# Epoch 12/20
# 101/101 [==============================] - 1s 9ms/step - loss: 1.4091 - root_mean_squared_error: 1.1871 - val_loss: 0.7246 - val_root_mean_squared_error: 0.8512
# Epoch 13/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.1450 - root_mean_squared_error: 1.0701 - val_loss: 0.8474 - val_root_mean_squared_error: 0.9206
# Epoch 14/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.0571 - root_mean_squared_error: 1.0282 - val_loss: 0.6547 - val_root_mean_squared_error: 0.8092
# Epoch 15/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.0135 - root_mean_squared_error: 1.0067 - val_loss: 0.6536 - val_root_mean_squared_error: 0.8084
# Epoch 16/20
# 101/101 [==============================] - 1s 9ms/step - loss: 1.0408 - root_mean_squared_error: 1.0202 - val_loss: 0.6802 - val_root_mean_squared_error: 0.8248
# Epoch 17/20
# 101/101 [==============================] - 1s 8ms/step - loss: 1.0213 - root_mean_squared_error: 1.0106 - val_loss: 0.6723 - val_root_mean_squared_error: 0.8200
# Epoch 18/20
# 101/101 [==============================] - 1s 7ms/step - loss: 1.0328 - root_mean_squared_error: 1.0163 - val_loss: 0.6422 - val_root_mean_squared_error: 0.8014
# Epoch 19/20
# 101/101 [==============================] - 1s 7ms/step - loss: 0.9874 - root_mean_squared_error: 0.9937 - val_loss: 0.8087 - val_root_mean_squared_error: 0.8993
# Epoch 20/20
# 101/101 [==============================] - 1s 6ms/step - loss: 1.0038 - root_mean_squared_error: 1.0019 - val_loss: 0.7448 - val_root_mean_squared_error: 0.8630

# %%
hist_df = pd.DataFrame(history.history)
hist_df = hist_df.rename({'root_mean_squared_error': 'rmse', 'val_root_mean_squared_error' : 'val_rmse'}, axis=1)


fn_plot_tf_hist(hist_df)
#.8172

# %%
# make predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
y_pred = np.append(y_train_pred, y_test_pred)
# Out:
# 101/101 [==============================] - 0s 2ms/step
# 26/26 [==============================] - 0s 2ms/step

# %%
res_df = y_df.copy()
res_df['pred'] = y_pred
res_df['datetime'] = res_df['datetime'].dt.date
res_df.head()
# Out:
#        datetime      temp      pred
# 24   2006-01-01  5.422222  5.239117
# 48   2006-01-02  1.694444  1.307800
# 72   2006-01-03  2.200000  2.287986
# 96   2006-01-04  1.666667  1.530950
# 120  2006-01-05  1.805556  2.554117

# %%
res_df.tail()
# Out:
#          datetime      temp      pred
# 96336  2016-12-27 -1.627778 -0.956289
# 96360  2016-12-28 -1.677778 -1.007731
# 96384  2016-12-29 -1.727778 -1.058833
# 96408  2016-12-30 -1.777778 -1.108827
# 96432  2016-12-31 -1.822222 -1.152071

# %%
fig, ax = plt.subplots(figsize = (15,6))

res_df.plot(x='datetime', y=['temp','pred'], ax = ax);

ax.vlines(res_df.iloc[X_train.shape[0]]['datetime'], 
          res_df['temp'].min(), 
          res_df['temp'].max(), color = 'k', 
          linewidth=3.0, zorder=10, alpha =0.8)

ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler , LabelEncoder

import warnings
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = 'D:\DNN\input' # location where input data is stored
outDir = '../../output' # location to store outputs
modelDir = '../models'
subDir = 'flower_photos'
altName = 'cnn_base'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

TEST_SIZE = 0.2

ALPHA = 0.001
EPOCHS = 100 # number of cycles to run
PATIENCE = 20
LR_PATIENCE = 10
FACTOR_LR = 0.1
BATCH_SIZE = 32 # inline of Training Rows being 60000
IMG_HEIGHT = 190
IMG_WIDTH = 190


# Set parameters for decoration of plots
params = {'legend.fontsize' : 'medium',
          'figure.figsize'  : (15,10),
          'axes.labelsize'  : 'medium',
          'axes.titlesize'  :'large',
          'xtick.labelsize' :'medium',
          'ytick.labelsize' :'medium',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm # type: ignore
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()
    


def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();


def fn_plot_label(tr_ds, ts_ds):
    
    plt.figure(figsize = (15,5)) # instantiate the figure
    
    plt.subplot(1,2,1) # first out of 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis = 0).numpy() # get the labels

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color = 'DarkBlue') # barplot the counts

    plt.xticks(range(len(unique)), class_names)

    plt.title('Training Set')

    plt.subplot(1,2,2)
    
    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis = 0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color = 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Test Set')

# %%
data_dir = os.path.join(inpDir, subDir)
data_dir
# Out:
# 'D:\\DNN\\input\\flower_photos'

# %%
os.listdir(data_dir)
# Out:
# ['daisy', 'dandelion', 'LICENSE.txt', 'roses', 'sunflowers', 'tulips']

# %%
# create training data
train_ds =tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, # path the the data directory
    validation_split=TEST_SIZE, # what ratio of validation data
    subset='training', # purpose
    seed=RANDOM_STATE, 
    image_size=[IMG_HEIGHT, IMG_WIDTH], ## @@@ WHAT!
    batch_size=BATCH_SIZE
)
# test data
test_ds =tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, # path the the data directory
    validation_split=TEST_SIZE, # what ratio of validation data
    subset='validation', # purpose
    seed=RANDOM_STATE, 
    image_size=[IMG_HEIGHT, IMG_WIDTH], ## @@@ WHAT!
    batch_size=BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
class_dict = { k : v for k,v in enumerate(class_names)}
class_dict
# Out:
# {0: 'daisy', 1: 'dandelion', 2: 'roses', 3: 'sunflowers', 4: 'tulips'}

# %%
num_classes = len(class_names)
num_classes
# Out:
# 5

# %%
plt.figure(figsize=(12,6))

for images, labels in train_ds.take(1):
    for i in range (BATCH_SIZE):
        plt.subplot(int(BATCH_SIZE/8), 8, i +1)
        plt.grid(False)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis('off')
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))

for images, labels in test_ds.take(1): # get me one batch
    
    for i in range (BATCH_SIZE): # loop over batch
        
        plt.subplot(int(BATCH_SIZE/8), 8, i +1) # access the axis
        
        plt.grid(False) # no to grid
        
        plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int
        
        plt.title(class_names[labels[i]])
        
        plt.axis('off')
    
    plt.tight_layout()

plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)
input_shape
# Out:
# (190, 190, 3)

# %%
reg_lambda = 0.005
def build_model(input_shape , num_classes):
    knl_init = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)
    knl_reg = tf.keras.regularizers.L2(reg_lambda)
    
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Rescaling(1./255.))

    ######Augmentation


    ########set1
    #####convulation 1
    model.add(tf.keras.layers.Conv2D(32, (3 ,3),
             kernel_initializer = knl_init ,
             kernel_regularizer=knl_reg,
             input_shape = input_shape)) #188*188*32
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Dropout(rate=0.12,seed=RANDOM_STATE))
    ##########pool1
    model.add(tf.keras.layers.MaxPooling2D((2,2))) #94*94*32

    ##########set2
    ##convolution 2
    model.add(tf.keras.layers.Conv2D(64, (3 ,3),
             kernel_initializer = knl_init ,kernel_regularizer=knl_reg ))   #92*92*64
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Dropout(rate=0.12,seed=RANDOM_STATE))
    ##########pool2
    model.add(tf.keras.layers.MaxPooling2D((2,2))) #46*46*64

    ##########set3
    ##convolution 3
    model.add(tf.keras.layers.Conv2D(128, (3 ,3),
             kernel_initializer = knl_init , kernel_regularizer=knl_reg))   #44*44*128

    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Dropout(rate=0.12,seed=RANDOM_STATE))
    ##########pool3
    model.add(tf.keras.layers.MaxPooling2D((2,2))) #22*22*128

    ##########set4
    ##convolution 4
    model.add(tf.keras.layers.Conv2D(256, (3 ,3),
             kernel_initializer = knl_init , kernel_regularizer=knl_reg))   #920*20*256

    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Dropout(rate=0.12,seed=RANDOM_STATE))
    ##########pool4
    model.add(tf.keras.layers.MaxPooling2D((2,2))) #10*10*256

    ##########set5
    ##convolution 5
    model.add(tf.keras.layers.Conv2D(512, (3 ,3),
             kernel_initializer = knl_init , kernel_regularizer=knl_reg))   #8*8*512

    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Dropout(rate=0.12,seed=RANDOM_STATE))
    ##########pool5
    model.add(tf.keras.layers.MaxPooling2D((2,2))) #4*4*512


    ##########set6
    ##convolution 6
    model.add(tf.keras.layers.Conv2D(1024, (3 ,3),
             kernel_initializer = knl_init , kernel_regularizer=knl_reg))   #2*2*1024

    ##head
    model.add(tf.keras.layers.Flatten())
 
    ##dense1
    model.add(tf.keras.layers.Dense(1024 , 
             kernel_initializer = knl_init ,
             kernel_regularizer=knl_reg,
             activation = 'relu' ))
    ##dense2
    model.add(tf.keras.layers.Dense(256 , 
             kernel_initializer = knl_init ,
             kernel_regularizer=knl_reg,
             activation = 'relu' ))
    ##dense3
    model.add(tf.keras.layers.Dense(128, 
             kernel_initializer = knl_init ,
             kernel_regularizer=knl_reg,
             activation = 'relu' ))
    ##dense4
    model.add(tf.keras.layers.Dense(64, 
             kernel_initializer = knl_init ,
              =knl_reg,
             activation = 'relu' ))
    ##dense5
    model.add(tf.keras.layers.Dense(num_classes))

    return model

# %%
model = build_model(input_shape , num_classes)
model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=ALPHA),
              
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              
              metrics=['accuracy'])

# %%
checkpoint_filepath = os.path.join(modelDir, subDir, 'flowers_base')

model_ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor = 'val_loss',
    mode = 'auto',
    verbose = 1 ,
    save_best_only = True)


es_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    patience=PATIENCE,
    mode='auto',
    baseline = None,
    verbose = 1 ,
    restore_best_weights=True)


lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1)

# %%
history = model.fit(train_ds, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS,
                    callbacks=[lr_callback, es_callback ,model_ckpt_callback ],
                    validation_data= test_ds )
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\dai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 92/92 [==============================] - ETA: 0s - loss: 16.8601 - accuracy: 0.3794
# Epoch 1: val_loss improved from inf to 12.04593, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 95s 969ms/step - loss: 16.8601 - accuracy: 0.3794 - val_loss: 12.0459 - val_accuracy: 0.1907 - lr: 0.0010
# Epoch 2/100
# 92/92 [==============================] - ETA: 0s - loss: 8.9932 - accuracy: 0.4942
# Epoch 2: val_loss improved from 12.04593 to 7.63715, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 86s 937ms/step - loss: 8.9932 - accuracy: 0.4942 - val_loss: 7.6371 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 3/100
# 92/92 [==============================] - ETA: 0s - loss: 5.9045 - accuracy: 0.5347
# Epoch 3: val_loss improved from 7.63715 to 6.09290, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 86s 936ms/step - loss: 5.9045 - accuracy: 0.5347 - val_loss: 6.0929 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 4/100
# 92/92 [==============================] - ETA: 0s - loss: 4.3844 - accuracy: 0.5777
# Epoch 4: val_loss improved from 6.09290 to 4.77805, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 941ms/step - loss: 4.3844 - accuracy: 0.5777 - val_loss: 4.7781 - val_accuracy: 0.2398 - lr: 0.0010
# Epoch 5/100
# 92/92 [==============================] - ETA: 0s - loss: 3.5310 - accuracy: 0.5937
# Epoch 5: val_loss improved from 4.77805 to 4.44965, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 943ms/step - loss: 3.5310 - accuracy: 0.5937 - val_loss: 4.4497 - val_accuracy: 0.2520 - lr: 0.0010
# Epoch 6/100
# 92/92 [==============================] - ETA: 0s - loss: 2.9526 - accuracy: 0.6189
# Epoch 6: val_loss improved from 4.44965 to 3.23832, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 89s 968ms/step - loss: 2.9526 - accuracy: 0.6189 - val_loss: 3.2383 - val_accuracy: 0.3924 - lr: 0.0010
# Epoch 7/100
# 92/92 [==============================] - ETA: 0s - loss: 2.5722 - accuracy: 0.6393
# Epoch 7: val_loss improved from 3.23832 to 3.00088, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 949ms/step - loss: 2.5722 - accuracy: 0.6393 - val_loss: 3.0009 - val_accuracy: 0.3856 - lr: 0.0010
# Epoch 8/100
# 92/92 [==============================] - ETA: 0s - loss: 2.4042 - accuracy: 0.6005
# Epoch 8: val_loss improved from 3.00088 to 2.68090, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 951ms/step - loss: 2.4042 - accuracy: 0.6005 - val_loss: 2.6809 - val_accuracy: 0.4128 - lr: 0.0010
# Epoch 9/100
# 92/92 [==============================] - ETA: 0s - loss: 2.1185 - accuracy: 0.6441
# Epoch 9: val_loss improved from 2.68090 to 2.26146, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 954ms/step - loss: 2.1185 - accuracy: 0.6441 - val_loss: 2.2615 - val_accuracy: 0.5736 - lr: 0.0010
# Epoch 10/100
# 92/92 [==============================] - ETA: 0s - loss: 1.9947 - accuracy: 0.6315
# Epoch 10: val_loss improved from 2.26146 to 2.15231, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 947ms/step - loss: 1.9947 - accuracy: 0.6315 - val_loss: 2.1523 - val_accuracy: 0.5531 - lr: 0.0010
# Epoch 11/100
# 92/92 [==============================] - ETA: 0s - loss: 1.9146 - accuracy: 0.6277
# Epoch 11: val_loss did not improve from 2.15231
# 92/92 [==============================] - 86s 930ms/step - loss: 1.9146 - accuracy: 0.6277 - val_loss: 2.2729 - val_accuracy: 0.4932 - lr: 0.0010
# Epoch 12/100
# 92/92 [==============================] - ETA: 0s - loss: 1.7891 - accuracy: 0.6522
# Epoch 12: val_loss improved from 2.15231 to 2.07000, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 89s 964ms/step - loss: 1.7891 - accuracy: 0.6522 - val_loss: 2.0700 - val_accuracy: 0.5409 - lr: 0.0010
# Epoch 13/100
# 92/92 [==============================] - ETA: 0s - loss: 1.7723 - accuracy: 0.6264
# Epoch 13: val_loss did not improve from 2.07000
# 92/92 [==============================] - 86s 934ms/step - loss: 1.7723 - accuracy: 0.6264 - val_loss: 3.3204 - val_accuracy: 0.2779 - lr: 0.0010
# Epoch 14/100
# 92/92 [==============================] - ETA: 0s - loss: 1.6891 - accuracy: 0.6390
# Epoch 14: val_loss improved from 2.07000 to 1.91780, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 951ms/step - loss: 1.6891 - accuracy: 0.6390 - val_loss: 1.9178 - val_accuracy: 0.5409 - lr: 0.0010
# Epoch 15/100
# 92/92 [==============================] - ETA: 0s - loss: 1.6494 - accuracy: 0.6441
# Epoch 15: val_loss improved from 1.91780 to 1.80602, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 946ms/step - loss: 1.6494 - accuracy: 0.6441 - val_loss: 1.8060 - val_accuracy: 0.5845 - lr: 0.0010
# Epoch 16/100
# 92/92 [==============================] - ETA: 0s - loss: 1.5453 - accuracy: 0.6645
# Epoch 16: val_loss did not improve from 1.80602
# 92/92 [==============================] - 86s 931ms/step - loss: 1.5453 - accuracy: 0.6645 - val_loss: 1.8266 - val_accuracy: 0.5886 - lr: 0.0010
# Epoch 17/100
# 92/92 [==============================] - ETA: 0s - loss: 1.5367 - accuracy: 0.6512
# Epoch 17: val_loss did not improve from 1.80602
# 92/92 [==============================] - 86s 935ms/step - loss: 1.5367 - accuracy: 0.6512 - val_loss: 1.8252 - val_accuracy: 0.5395 - lr: 0.0010
# Epoch 18/100
# 92/92 [==============================] - ETA: 0s - loss: 1.5125 - accuracy: 0.6683
# Epoch 18: val_loss did not improve from 1.80602
# 92/92 [==============================] - 86s 936ms/step - loss: 1.5125 - accuracy: 0.6683 - val_loss: 2.4715 - val_accuracy: 0.3583 - lr: 0.0010
# Epoch 19/100
# 92/92 [==============================] - ETA: 0s - loss: 1.4745 - accuracy: 0.6584
# Epoch 19: val_loss did not improve from 1.80602
# 92/92 [==============================] - 86s 932ms/step - loss: 1.4745 - accuracy: 0.6584 - val_loss: 2.1226 - val_accuracy: 0.4155 - lr: 0.0010
# Epoch 20/100
# 92/92 [==============================] - ETA: 0s - loss: 1.4087 - accuracy: 0.6856
# Epoch 20: val_loss improved from 1.80602 to 1.65074, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 943ms/step - loss: 1.4087 - accuracy: 0.6856 - val_loss: 1.6507 - val_accuracy: 0.5627 - lr: 0.0010
# Epoch 21/100
# 92/92 [==============================] - ETA: 0s - loss: 1.4107 - accuracy: 0.6829
# Epoch 21: val_loss did not improve from 1.65074
# 92/92 [==============================] - 86s 931ms/step - loss: 1.4107 - accuracy: 0.6829 - val_loss: 1.7383 - val_accuracy: 0.5136 - lr: 0.0010
# Epoch 22/100
# 92/92 [==============================] - ETA: 0s - loss: 1.3449 - accuracy: 0.6901
# Epoch 22: val_loss did not improve from 1.65074
# 92/92 [==============================] - 86s 930ms/step - loss: 1.3449 - accuracy: 0.6901 - val_loss: 1.8051 - val_accuracy: 0.5341 - lr: 0.0010
# Epoch 23/100
# 92/92 [==============================] - ETA: 0s - loss: 1.3826 - accuracy: 0.6747
# Epoch 23: val_loss did not improve from 1.65074
# 92/92 [==============================] - 86s 939ms/step - loss: 1.3826 - accuracy: 0.6747 - val_loss: 1.9501 - val_accuracy: 0.4564 - lr: 0.0010
# Epoch 24/100
# 92/92 [==============================] - ETA: 0s - loss: 1.3619 - accuracy: 0.6802
# Epoch 24: val_loss did not improve from 1.65074
# 92/92 [==============================] - 87s 950ms/step - loss: 1.3619 - accuracy: 0.6802 - val_loss: 1.8858 - val_accuracy: 0.4932 - lr: 0.0010
# Epoch 25/100
# 92/92 [==============================] - ETA: 0s - loss: 1.3049 - accuracy: 0.6921
# Epoch 25: val_loss improved from 1.65074 to 1.57616, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 953ms/step - loss: 1.3049 - accuracy: 0.6921 - val_loss: 1.5762 - val_accuracy: 0.5817 - lr: 0.0010
# Epoch 26/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2535 - accuracy: 0.7020
# Epoch 26: val_loss did not improve from 1.57616
# 92/92 [==============================] - 86s 935ms/step - loss: 1.2535 - accuracy: 0.7020 - val_loss: 2.4356 - val_accuracy: 0.3965 - lr: 0.0010
# Epoch 27/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2398 - accuracy: 0.7003
# Epoch 27: val_loss improved from 1.57616 to 1.35330, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 953ms/step - loss: 1.2398 - accuracy: 0.7003 - val_loss: 1.3533 - val_accuracy: 0.6567 - lr: 0.0010
# Epoch 28/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2159 - accuracy: 0.7142
# Epoch 28: val_loss did not improve from 1.35330
# 92/92 [==============================] - 87s 948ms/step - loss: 1.2159 - accuracy: 0.7142 - val_loss: 1.4164 - val_accuracy: 0.6376 - lr: 0.0010
# Epoch 29/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2117 - accuracy: 0.7040
# Epoch 29: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 932ms/step - loss: 1.2117 - accuracy: 0.7040 - val_loss: 1.6594 - val_accuracy: 0.5014 - lr: 0.0010
# Epoch 30/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1797 - accuracy: 0.7166
# Epoch 30: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 937ms/step - loss: 1.1797 - accuracy: 0.7166 - val_loss: 1.5913 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 31/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1738 - accuracy: 0.7047
# Epoch 31: val_loss did not improve from 1.35330
# 92/92 [==============================] - 89s 969ms/step - loss: 1.1738 - accuracy: 0.7047 - val_loss: 1.7765 - val_accuracy: 0.5082 - lr: 0.0010
# Epoch 32/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1747 - accuracy: 0.7187
# Epoch 32: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 932ms/step - loss: 1.1747 - accuracy: 0.7187 - val_loss: 1.5239 - val_accuracy: 0.5531 - lr: 0.0010
# Epoch 33/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2178 - accuracy: 0.6962
# Epoch 33: val_loss did not improve from 1.35330
# 92/92 [==============================] - 87s 945ms/step - loss: 1.2178 - accuracy: 0.6962 - val_loss: 1.5090 - val_accuracy: 0.5599 - lr: 0.0010
# Epoch 34/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1748 - accuracy: 0.7136
# Epoch 34: val_loss did not improve from 1.35330
# 92/92 [==============================] - 88s 954ms/step - loss: 1.1748 - accuracy: 0.7136 - val_loss: 1.5641 - val_accuracy: 0.5436 - lr: 0.0010
# Epoch 35/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2136 - accuracy: 0.7013
# Epoch 35: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 936ms/step - loss: 1.2136 - accuracy: 0.7013 - val_loss: 1.6757 - val_accuracy: 0.5136 - lr: 0.0010
# Epoch 36/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1337 - accuracy: 0.7217
# Epoch 36: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 930ms/step - loss: 1.1337 - accuracy: 0.7217 - val_loss: 1.8928 - val_accuracy: 0.4469 - lr: 0.0010
# Epoch 37/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1164 - accuracy: 0.7292
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 37: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 933ms/step - loss: 1.1164 - accuracy: 0.7292 - val_loss: 1.4904 - val_accuracy: 0.5572 - lr: 0.0010
# Epoch 38/100
# 92/92 [==============================] - ETA: 0s - loss: 0.9291 - accuracy: 0.7796
# Epoch 38: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 935ms/step - loss: 0.9291 - accuracy: 0.7796 - val_loss: 1.8537 - val_accuracy: 0.4210 - lr: 1.0000e-04
# Epoch 39/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8579 - accuracy: 0.7980
# Epoch 39: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 938ms/step - loss: 0.8579 - accuracy: 0.7980 - val_loss: 1.7746 - val_accuracy: 0.4292 - lr: 1.0000e-04
# Epoch 40/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8201 - accuracy: 0.8082
# Epoch 40: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 930ms/step - loss: 0.8201 - accuracy: 0.8082 - val_loss: 1.7724 - val_accuracy: 0.4196 - lr: 1.0000e-04
# Epoch 41/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8078 - accuracy: 0.7994
# Epoch 41: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 929ms/step - loss: 0.8078 - accuracy: 0.7994 - val_loss: 1.6077 - val_accuracy: 0.5041 - lr: 1.0000e-04
# Epoch 42/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7968 - accuracy: 0.8065
# Epoch 42: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 932ms/step - loss: 0.7968 - accuracy: 0.8065 - val_loss: 1.4459 - val_accuracy: 0.5531 - lr: 1.0000e-04
# Epoch 43/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7794 - accuracy: 0.8134
# Epoch 43: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 929ms/step - loss: 0.7794 - accuracy: 0.8134 - val_loss: 1.4340 - val_accuracy: 0.5831 - lr: 1.0000e-04
# Epoch 44/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.8219
# Epoch 44: val_loss did not improve from 1.35330
# 92/92 [==============================] - 86s 930ms/step - loss: 0.7498 - accuracy: 0.8219 - val_loss: 1.5009 - val_accuracy: 0.5722 - lr: 1.0000e-04
# Epoch 45/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7250 - accuracy: 0.8277
# Epoch 45: val_loss improved from 1.35330 to 1.17019, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 952ms/step - loss: 0.7250 - accuracy: 0.8277 - val_loss: 1.1702 - val_accuracy: 0.6621 - lr: 1.0000e-04
# Epoch 46/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7327 - accuracy: 0.8283
# Epoch 46: val_loss did not improve from 1.17019
# 92/92 [==============================] - 86s 932ms/step - loss: 0.7327 - accuracy: 0.8283 - val_loss: 1.1867 - val_accuracy: 0.6567 - lr: 1.0000e-04
# Epoch 47/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.8406
# Epoch 47: val_loss did not improve from 1.17019
# 92/92 [==============================] - 86s 931ms/step - loss: 0.6962 - accuracy: 0.8406 - val_loss: 1.4153 - val_accuracy: 0.6076 - lr: 1.0000e-04
# Epoch 48/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.8450
# Epoch 48: val_loss did not improve from 1.17019
# 92/92 [==============================] - 86s 929ms/step - loss: 0.6934 - accuracy: 0.8450 - val_loss: 1.1813 - val_accuracy: 0.6662 - lr: 1.0000e-04
# Epoch 49/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.8522
# Epoch 49: val_loss did not improve from 1.17019
# 92/92 [==============================] - 86s 932ms/step - loss: 0.6846 - accuracy: 0.8522 - val_loss: 1.2447 - val_accuracy: 0.6322 - lr: 1.0000e-04
# Epoch 50/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.8474
# Epoch 50: val_loss did not improve from 1.17019
# 92/92 [==============================] - 86s 937ms/step - loss: 0.6833 - accuracy: 0.8474 - val_loss: 1.3709 - val_accuracy: 0.6022 - lr: 1.0000e-04
# Epoch 51/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6581 - accuracy: 0.8583
# Epoch 51: val_loss did not improve from 1.17019
# 92/92 [==============================] - 86s 932ms/step - loss: 0.6581 - accuracy: 0.8583 - val_loss: 1.3128 - val_accuracy: 0.6294 - lr: 1.0000e-04
# Epoch 52/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6337 - accuracy: 0.8678
# Epoch 52: val_loss improved from 1.17019 to 1.14678, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 956ms/step - loss: 0.6337 - accuracy: 0.8678 - val_loss: 1.1468 - val_accuracy: 0.6826 - lr: 1.0000e-04
# Epoch 53/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.8699
# Epoch 53: val_loss improved from 1.14678 to 1.12199, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 949ms/step - loss: 0.6239 - accuracy: 0.8699 - val_loss: 1.1220 - val_accuracy: 0.7016 - lr: 1.0000e-04
# Epoch 54/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6123 - accuracy: 0.8723
# Epoch 54: val_loss did not improve from 1.12199
# 92/92 [==============================] - 86s 937ms/step - loss: 0.6123 - accuracy: 0.8723 - val_loss: 1.1542 - val_accuracy: 0.6812 - lr: 1.0000e-04
# Epoch 55/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.8811
# Epoch 55: val_loss did not improve from 1.12199
# 92/92 [==============================] - 86s 934ms/step - loss: 0.5956 - accuracy: 0.8811 - val_loss: 1.1919 - val_accuracy: 0.6567 - lr: 1.0000e-04
# Epoch 56/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5765 - accuracy: 0.8924
# Epoch 56: val_loss did not improve from 1.12199
# 92/92 [==============================] - 86s 930ms/step - loss: 0.5765 - accuracy: 0.8924 - val_loss: 1.2518 - val_accuracy: 0.6676 - lr: 1.0000e-04
# Epoch 57/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5512 - accuracy: 0.9005
# Epoch 57: val_loss did not improve from 1.12199
# 92/92 [==============================] - 86s 931ms/step - loss: 0.5512 - accuracy: 0.9005 - val_loss: 1.1928 - val_accuracy: 0.6567 - lr: 1.0000e-04
# Epoch 58/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5438 - accuracy: 0.9040
# Epoch 58: val_loss did not improve from 1.12199
# 92/92 [==============================] - 86s 935ms/step - loss: 0.5438 - accuracy: 0.9040 - val_loss: 1.5236 - val_accuracy: 0.5886 - lr: 1.0000e-04
# Epoch 59/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5146 - accuracy: 0.9101
# Epoch 59: val_loss did not improve from 1.12199
# 92/92 [==============================] - 87s 942ms/step - loss: 0.5146 - accuracy: 0.9101 - val_loss: 1.1580 - val_accuracy: 0.6798 - lr: 1.0000e-04
# Epoch 60/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5240 - accuracy: 0.9053
# Epoch 60: val_loss improved from 1.12199 to 1.11798, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 954ms/step - loss: 0.5240 - accuracy: 0.9053 - val_loss: 1.1180 - val_accuracy: 0.7071 - lr: 1.0000e-04
# Epoch 61/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.9186
# Epoch 61: val_loss did not improve from 1.11798
# 92/92 [==============================] - 86s 932ms/step - loss: 0.5043 - accuracy: 0.9186 - val_loss: 1.1925 - val_accuracy: 0.6703 - lr: 1.0000e-04
# Epoch 62/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.9183
# Epoch 62: val_loss did not improve from 1.11798
# 92/92 [==============================] - 86s 934ms/step - loss: 0.5026 - accuracy: 0.9183 - val_loss: 1.2103 - val_accuracy: 0.6907 - lr: 1.0000e-04
# Epoch 63/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.9183
# Epoch 63: val_loss improved from 1.11798 to 1.05993, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 87s 948ms/step - loss: 0.4986 - accuracy: 0.9183 - val_loss: 1.0599 - val_accuracy: 0.7343 - lr: 1.0000e-04
# Epoch 64/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4734 - accuracy: 0.9285
# Epoch 64: val_loss did not improve from 1.05993
# 92/92 [==============================] - 86s 930ms/step - loss: 0.4734 - accuracy: 0.9285 - val_loss: 1.7373 - val_accuracy: 0.5790 - lr: 1.0000e-04
# Epoch 65/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4593 - accuracy: 0.9370
# Epoch 65: val_loss did not improve from 1.05993
# 92/92 [==============================] - 86s 934ms/step - loss: 0.4593 - accuracy: 0.9370 - val_loss: 1.6069 - val_accuracy: 0.6417 - lr: 1.0000e-04
# Epoch 66/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4572 - accuracy: 0.9346
# Epoch 66: val_loss did not improve from 1.05993
# 92/92 [==============================] - 87s 946ms/step - loss: 0.4572 - accuracy: 0.9346 - val_loss: 1.2854 - val_accuracy: 0.6744 - lr: 1.0000e-04
# Epoch 67/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.9475
# Epoch 67: val_loss did not improve from 1.05993
# 92/92 [==============================] - 86s 933ms/step - loss: 0.4311 - accuracy: 0.9475 - val_loss: 1.1750 - val_accuracy: 0.6907 - lr: 1.0000e-04
# Epoch 68/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.9435
# Epoch 68: val_loss did not improve from 1.05993
# 92/92 [==============================] - 85s 928ms/step - loss: 0.4394 - accuracy: 0.9435 - val_loss: 1.2410 - val_accuracy: 0.6608 - lr: 1.0000e-04
# Epoch 69/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4186 - accuracy: 0.9472
# Epoch 69: val_loss did not improve from 1.05993
# 92/92 [==============================] - 86s 933ms/step - loss: 0.4186 - accuracy: 0.9472 - val_loss: 1.1878 - val_accuracy: 0.7112 - lr: 1.0000e-04
# Epoch 70/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.9601
# Epoch 70: val_loss improved from 1.05993 to 0.92225, saving model to ../models\flower_photos\flowers_base
# 92/92 [==============================] - 88s 958ms/step - loss: 0.3973 - accuracy: 0.9601 - val_loss: 0.9222 - val_accuracy: 0.7711 - lr: 1.0000e-04
# Epoch 71/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.9544
# Epoch 71: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 931ms/step - loss: 0.4083 - accuracy: 0.9544 - val_loss: 1.4662 - val_accuracy: 0.6458 - lr: 1.0000e-04
# Epoch 72/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3997 - accuracy: 0.9605
# Epoch 72: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 932ms/step - loss: 0.3997 - accuracy: 0.9605 - val_loss: 1.0600 - val_accuracy: 0.7371 - lr: 1.0000e-04
# Epoch 73/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3870 - accuracy: 0.9632
# Epoch 73: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 935ms/step - loss: 0.3870 - accuracy: 0.9632 - val_loss: 1.4112 - val_accuracy: 0.6744 - lr: 1.0000e-04
# Epoch 74/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3936 - accuracy: 0.9588
# Epoch 74: val_loss did not improve from 0.92225
# 92/92 [==============================] - 85s 927ms/step - loss: 0.3936 - accuracy: 0.9588 - val_loss: 1.0779 - val_accuracy: 0.7343 - lr: 1.0000e-04
# Epoch 75/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.9721
# Epoch 75: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 930ms/step - loss: 0.3609 - accuracy: 0.9721 - val_loss: 1.3785 - val_accuracy: 0.6717 - lr: 1.0000e-04
# Epoch 76/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.9571
# Epoch 76: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 932ms/step - loss: 0.4042 - accuracy: 0.9571 - val_loss: 0.9332 - val_accuracy: 0.7738 - lr: 1.0000e-04
# Epoch 77/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3811 - accuracy: 0.9663
# Epoch 77: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 932ms/step - loss: 0.3811 - accuracy: 0.9663 - val_loss: 1.6064 - val_accuracy: 0.6703 - lr: 1.0000e-04
# Epoch 78/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.9785
# Epoch 78: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 930ms/step - loss: 0.3430 - accuracy: 0.9785 - val_loss: 1.1695 - val_accuracy: 0.7289 - lr: 1.0000e-04
# Epoch 79/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.9700
# Epoch 79: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 935ms/step - loss: 0.3537 - accuracy: 0.9700 - val_loss: 1.0578 - val_accuracy: 0.7248 - lr: 1.0000e-04
# Epoch 80/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.9547
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 80: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 938ms/step - loss: 0.3971 - accuracy: 0.9547 - val_loss: 1.0794 - val_accuracy: 0.7425 - lr: 1.0000e-04
# Epoch 81/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3158 - accuracy: 0.9864
# Epoch 81: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 937ms/step - loss: 0.3158 - accuracy: 0.9864 - val_loss: 1.1201 - val_accuracy: 0.7262 - lr: 1.0000e-05
# Epoch 82/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.9922
# Epoch 82: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 932ms/step - loss: 0.3070 - accuracy: 0.9922 - val_loss: 1.1179 - val_accuracy: 0.7371 - lr: 1.0000e-05
# Epoch 83/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.9935
# Epoch 83: val_loss did not improve from 0.92225
# 92/92 [==============================] - 85s 928ms/step - loss: 0.2987 - accuracy: 0.9935 - val_loss: 1.0722 - val_accuracy: 0.7371 - lr: 1.0000e-05
# Epoch 84/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.9969
# Epoch 84: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 931ms/step - loss: 0.2899 - accuracy: 0.9969 - val_loss: 1.0422 - val_accuracy: 0.7493 - lr: 1.0000e-05
# Epoch 85/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.9946
# Epoch 85: val_loss did not improve from 0.92225
# 92/92 [==============================] - 88s 959ms/step - loss: 0.2929 - accuracy: 0.9946 - val_loss: 1.0378 - val_accuracy: 0.7507 - lr: 1.0000e-05
# Epoch 86/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9959
# Epoch 86: val_loss did not improve from 0.92225
# 92/92 [==============================] - 88s 952ms/step - loss: 0.2871 - accuracy: 0.9959 - val_loss: 1.0337 - val_accuracy: 0.7480 - lr: 1.0000e-05
# Epoch 87/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9976
# Epoch 87: val_loss did not improve from 0.92225
# 92/92 [==============================] - 85s 924ms/step - loss: 0.2796 - accuracy: 0.9976 - val_loss: 1.0218 - val_accuracy: 0.7520 - lr: 1.0000e-05
# Epoch 88/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.9966
# Epoch 88: val_loss did not improve from 0.92225
# 92/92 [==============================] - 85s 925ms/step - loss: 0.2840 - accuracy: 0.9966 - val_loss: 1.0360 - val_accuracy: 0.7548 - lr: 1.0000e-05
# Epoch 89/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9959
# Epoch 89: val_loss did not improve from 0.92225
# 92/92 [==============================] - 85s 924ms/step - loss: 0.2796 - accuracy: 0.9959 - val_loss: 1.0078 - val_accuracy: 0.7575 - lr: 1.0000e-05
# Epoch 90/100
# 92/92 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.9963
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Restoring model weights from the end of the best epoch: 70.
#
# Epoch 90: val_loss did not improve from 0.92225
# 92/92 [==============================] - 86s 934ms/step - loss: 0.2789 - accuracy: 0.9963 - val_loss: 1.0630 - val_accuracy: 0.7520 - lr: 1.0000e-05
# Epoch 90: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 190, 190, 3)       0
#
#  conv2d_7 (Conv2D)           (None, 188, 188, 32)      896
#
#  batch_normalization_6 (Bat  (None, 188, 188, 32)      128
#  chNormalization)
#
#  activation_6 (Activation)   (None, 188, 188, 32)      0
#
#  dropout_6 (Dropout)         (None, 188, 188, 32)      0
#
#  max_pooling2d_6 (MaxPoolin  (None, 94, 94, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 92, 92, 64)        18496
#
#  batch_normalization_7 (Bat  (None, 92, 92, 64)        256
#  chNormalization)
#
#  activation_7 (Activation)   (None, 92, 92, 64)        0
#
#  dropout_7 (Dropout)         (None, 92, 92, 64)        0
#
#  max_pooling2d_7 (MaxPoolin  (None, 46, 46, 64)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 44, 44, 128)       73856
#
#  batch_normalization_8 (Bat  (None, 44, 44, 128)       512
#  chNormalization)
#
#  activation_8 (Activation)   (None, 44, 44, 128)       0
#
#  dropout_8 (Dropout)         (None, 44, 44, 128)       0
#
#  max_pooling2d_8 (MaxPoolin  (None, 22, 22, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 20, 20, 256)       295168
#
#  batch_normalization_9 (Bat  (None, 20, 20, 256)       1024
#  chNormalization)
#
#  activation_9 (Activation)   (None, 20, 20, 256)       0
#
#  dropout_9 (Dropout)         (None, 20, 20, 256)       0
#
#  max_pooling2d_9 (MaxPoolin  (None, 10, 10, 256)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_10 (Ba  (None, 8, 8, 512)         2048
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 8, 8, 512)         0
#
#  dropout_10 (Dropout)        (None, 8, 8, 512)         0
#
#  max_pooling2d_10 (MaxPooli  (None, 4, 4, 512)         0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 2, 2, 1024)        4719616
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1024)              4195328
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 10791365 (41.17 MB)
# Trainable params: 10789381 (41.16 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(history.history)

fn_plot_tf_hist(loss_df)

# %%
test_loss, test_acc = model.evaluate(test_ds, verbose=2)
# Out:
# 23/23 - 4s - loss: 0.9222 - accuracy: 0.7711 - 4s/epoch - 192ms/step

# %%
yhat = model.predict(test_ds)
# Out:
# 23/23 [==============================] - 4s 182ms/step

# %%
y_test = tf.concat([y for x, y in test_ds], axis=0).numpy()

# %%
y_pred = yhat.argmax(axis = 1)

print('Accuracy score on Test Data :', accuracy_score(y_test, y_pred))
# Out:
# Accuracy score on Test Data : 0.2438692098092643

# %%
layer = tf.keras.layers.RandomRotation((-0.5,0.5) ,  fill_mode='nearest', seed=RANDOM_STATE)

plt.figure()

img_num = 0
for images, labels in train_ds.take(1):
    out_image = layer(images)
    plt.subplot(1,2,1)
    plt.title("Original")
    plt.imshow(images[img_num].numpy().astype('uint16'))
    plt.grid(False)


    plt.subplot(1,2,2)
    plt.title("Rotated")
    plt.imshow(out_image[img_num].numpy().astype('uint16'))
    plt.grid(False)
